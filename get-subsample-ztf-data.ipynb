# %% [markdown]
# # First algorithmic question:
# how to identify high-cadence subsets within arbitrary sparse lightcurves?

# %% [markdown]
# Ideas:
# 1. select all observations for a given object (even with catflags $\neq 0$)
# 2. concatenate mjd with all filters and sort this array by their value of mjd
#     * or do this with same filter?
#     * or do this just with the r-band
#         * from the high cadence survey paper (https://academic.oup.com/mnras/article/505/1/1254/6274690)
#             * All observations of the high-cadence Galactic plane survey were obtained in ZTF-r band.
# 3. using the sorted array of mjd define an array of $\Delta t$
# 4. define max_dt between observations to be considered high-cadence
# 5. define min_len(ght) of continuous observations to be considered high-cadence
#     * because one can have consecutive observations of 4 adjacent fields ($> 4$)
#         * from the high cadence survey paper (https://academic.oup.com/mnras/article/505/1/1254/6274690)
#             * cadence of 40 sec
#             * either observed one field or alternated between two adjacent fields continuously for ≈1.5–3 h on two to three consecutive nights in the ZTF-r band.
#                 * In June, we observed every field continuously for 1 h15 min and in July for 1 h 25 min.
#                 * We alternated between two adjacent fields continuously for 2 h 40min each night. Because more time was available each night most fields were observed for ≈3 h. The same fields were repeated the following night.
#                 * We lost only a total of five nights due to weather during June/July and August observations.
#
# Idea: high cadence observations with $\Delta t_{max}$ of $4 \cdot 40s$  (160 s) during at least 1 hr 15 min (or 1 hr) $\approx 22 - 28 $ observations

# %%
sec_to_day = 1 / (24 * 60 * 60)
max_dt_hc = 4 * 40 * sec_to_day

min_consec_obs = int((75 * 60) / (4 * 40))

# %%
min_consec_obs
# Out:
# 28

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import astropy.units as u
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
from matplotlib import rcParams
rcParams['savefig.dpi'] = 550
rcParams['font.size'] = 20
plt.rc('font', family='serif')

import lsdb
#from lsdb import lsdb_client
#client = lsdb_client(dask_on_ray=False, num_workers=12)

import tape

import dask 

dask.config.set({"temporary-directory" :'/epyc/ssd/users/fbcb/tmp'})

from dask.distributed import Client
client = Client(n_workers=10, threads_per_worker=10,
                memory_limit="60G")
# Out:
# 2024-02-23 14:36:57,651 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:36221'.
# 2024-02-23 14:36:57,759 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:36450'.
# 2024-02-23 14:36:57,851 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:37950'.
# 2024-02-23 14:36:57,947 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:46235'.
# 2024-02-23 14:36:58,039 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:43069'.
# 2024-02-23 14:36:58,098 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:42731'.
# 2024-02-23 14:36:58,132 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:35970'.
# 2024-02-23 14:36:58,186 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:39239'.
# 2024-02-23 14:36:58,253 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:33827'.
# 2024-02-23 14:36:58,291 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:46534'.

# %% [markdown]
# # Function to get high cadence data

# %%
def identify_hc_objects_band(mjd, band, flag, mag, magerr, band_name, 
                             max_dt = max_dt_hc, min_len = min_consec_obs):
    
    if (band.size > 0):
        
        arr_band_name = np.array([band_name])
        bands_obs = np.unique(band)
    
        if np.isin(arr_band_name, bands_obs, invert=True)[0]:
            return 0, np.nan, np.nan

        band_mask = ((band == band_name) & (flag == 0) & (magerr>0)  
                    & (~np.isnan(mjd)) & (~np.isnan(mag)) & (~np.isnan(magerr))) # remove nans!
    
        if np.sum(band_mask) == 0:
            return 0, np.nan, np.nan
    
        else:
                # sort time
            srt = mjd.argsort() # np.array(mjd).argsort()
            mjd = mjd[srt] # np.array(mjd)[srt]
        
            mjd_band = mjd[band_mask]
    
            num_obs = len(mjd_band)
    
            if num_obs < min_len:
                return 0, np.nan, np.nan
    
            else:
                    # calculate the difference in mjd for the same band
                dt = np.diff(mjd_band)
                len_dt = num_obs - 1
        
                    # create an array of indexes of delta t
                idx_dt = np.indices((len_dt,))[0]
    
                    # create a mask indicating if dt > max_dt
                above_max_dt = (dt > max_dt)
        
                    # select indexes that satisfy dt > max_dt
                idx_mask = idx_dt[above_max_dt]
            
                    # all observations are hc observations
                if (len(idx_mask) == 0):
                    mjd_start_hc = np.min(mjd_band)
                    mjd_end_hc = np.max(mjd_band)
                    return 1, mjd_start_hc, mjd_end_hc
            
                else:
                        # edge cases
                    idx_0 = idx_mask[0]
                    last_idx = idx_mask[-1]
                
                    first_obs_hc = (idx_0 >= min_len)
                    last_obs_hc = (len_dt - last_idx >= min_len)
                
                        # center case
                    idx_mask_diff = np.diff(idx_mask)
                    high_cadence_mask = (idx_mask_diff >= (min_len + 1))
                    center_obs_hc = (np.sum(high_cadence_mask) >= 1)
                    
                    if center_obs_hc:
                        idx_start_hc = idx_mask[:-1][high_cadence_mask] + 1
                        idx_end_hc = idx_start_hc + idx_mask_diff[high_cadence_mask] - 1
                        
                        mjd_start_hc = mjd_band[idx_start_hc]
                        mjd_end_hc = mjd_band[idx_end_hc]
                    
                        if first_obs_hc:
                            mjd_1st_hc_start = np.min(mjd_band)
                            mjd_1st_hc_end = mjd_band[idx_0 - 1]
                        
                            mjd_s_hc = np.append(mjd_1st_hc_start, mjd_start_hc)
                            mjd_e_hc = np.append(mjd_1st_hc_end, mjd_end_hc)
                        
                            if last_obs_hc:
                                mjd_last_hc_start = mjd_band[last_idx + 1]
                                mjd_last_hc_end = mjd_band[-1]
                            
                                mjd_s_hc = np.append(mjd_s_hc, mjd_last_hc_start)
                                mjd_e_hc = np.append(mjd_e_hc, mjd_last_hc_end)
                            
                                return 1, mjd_s_hc, mjd_e_hc
                        
                            else:
                                return 1, mjd_s_hc, mjd_e_hc
                        
                        elif last_obs_hc:
                            
                            mjd_last_hc_start = mjd_band[last_idx + 1]
                            mjd_last_hc_end = mjd_band[-1]
                            
                            mjd_s_hc = np.append(mjd_start_hc, mjd_last_hc_start)
                            mjd_e_hc = np.append(mjd_end_hc, mjd_last_hc_end)
                        
                            return 1, mjd_s_hc, mjd_e_hc 
                        
                        else:
                            return 1, mjd_start_hc, mjd_end_hc
                    
                
                    elif first_obs_hc:
                        mjd_1st_hc_start = np.min(mjd_band)
                        mjd_1st_hc_end = mjd_band[idx_0 - 1]
                        
                        if last_obs_hc:
                            mjd_last_hc_start = mjd_band[last_idx + 1]
                            mjd_last_hc_end = mjd_band[-1]
                            
                            mjd_s_hc = np.append(mjd_1st_hc_start, mjd_last_hc_start)
                            mjd_e_hc = np.append(mjd_1st_hc_end, mjd_last_hc_end)
                            
                            return 1, mjd_s_hc, mjd_e_hc
                        
                        else:
                            return 1, mjd_1st_hc_start, mjd_1st_hc_end
                    
                    elif last_obs_hc:
                        mjd_last_hc_start = mjd_band[last_idx + 1]
                        mjd_last_hc_end = mjd_band[-1]
                            
                        return 1, mjd_last_hc_start, mjd_last_hc_end
                
                    else:
                        return 0, np.nan, np.nan

    else:
        return 0, np.nan, np.nan

# %%
# Define output columns
output_cols = ["high_cad_g", "mjd_start_high_cad_g", "mjd_end_high_cad_g", 
               "high_cad_r", "mjd_start_high_cad_r", "mjd_end_high_cad_r",
               "high_cad_i", "mjd_start_high_cad_i", "mjd_end_high_cad_i",]

# Define DataFrame with loc and scale as meta
my_meta = pd.DataFrame(columns=output_cols, dtype=float)

# ** kwargs
def determine_hc(mjd, band, flag, mag, magerr): #**kwargs
    # determine if a given object has high cadence observations in any band
    
    hc_g, mjd_s_g, mjd_e_g = identify_hc_objects_band(mjd, band, flag, mag, magerr, 'g')
    hc_r, mjd_s_r, mjd_e_r = identify_hc_objects_band(mjd, band, flag, mag, magerr, 'r')
    hc_i, mjd_s_i, mjd_e_i = identify_hc_objects_band(mjd, band, flag, mag, magerr, 'i')
    
    return pd.Series([hc_g, mjd_s_g, mjd_e_g, hc_r, mjd_s_r, mjd_e_r, hc_i, mjd_s_i, mjd_e_i],index=output_cols)

# %% [markdown]
# # Try to do this with tape

# %% [markdown]
# Need to run output_cols and my_meta again

# %%
import dask.dataframe as dd
from tape import Ensemble, ColumnMapper

# %%
# Initialize an Ensemble
ens = Ensemble(client=client)
ens.client_info()
# Out:
# <Client: 'tcp://127.0.0.1:36650' processes=10 threads=100, memory=558.79 GiB>

# %%
# ColumnMapper Establishes which table columns map to timeseries quantities
colmap = ColumnMapper(
        id_col='_hipscat_index',
        time_col='mjd',
        flux_col='mag',
        err_col='magerr',
        band_col='band',
      )

# %%
# We can read from parquet
ens.from_hipscat(
    "/data3/epyc/data3/hipscat/catalogs/ztf_axs/ztf_source",
    "/data3/epyc/data3/hipscat/catalogs/ztf_axs/ztf_dr14",
    column_mapper=colmap,
    object_index='ps1_objid',
    source_index='ps1_objid')

# %%
ens.source.partitions[0:1].update_ensemble()
ens.object.partitions[0:1].update_ensemble()

# %%
ens.save_ensemble(
    ".",
    "ensemble_test")
# Out:
# /astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 60.95 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
# restart the kernel and the client
new_ens = Ensemble()
new_ens.from_ensemble('./ensemble_test')

# %%
ens.source.persist().update_ensemble()
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7fcacd26e980>>
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 770, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# 2024-02-23 14:36:57,367 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:60692 remote=tcp://127.0.0.1:36650>: Stream is closed
# 2024-02-23 14:36:57,386 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:60712 remote=tcp://127.0.0.1:36650>: Stream is closed
# 2024-02-23 14:36:57,387 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:60654 remote=tcp://127.0.0.1:36650>: Stream is closed
# 2024-02-23 14:36:57,526 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:60732 remote=tcp://127.0.0.1:36650>: Stream is closed
# 2024-02-23 14:36:57,553 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:60672 remote=tcp://127.0.0.1:36650>: Stream is closed
# 2024-02-23 14:36:57,566 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:60662 remote=tcp://127.0.0.1:36650>: Stream is closed
# 2024-02-23 14:36:57,566 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:60724 remote=tcp://127.0.0.1:36650>: Stream is closed
# 2024-02-23 14:36:57,566 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:60696 remote=tcp://127.0.0.1:36650>: Stream is closed
# 2024-02-23 14:36:57,587 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:60616 remote=tcp://127.0.0.1:36650>: Stream is closed
# 2024-02-23 14:36:57,625 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:60716 remote=tcp://127.0.0.1:36650>: Stream is closed
# Process Dask Worker process (from Nanny):
# 2024-02-23 14:36:59,379 - distributed.nanny - ERROR - Worker process died unexpectedly
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# 2024-02-23 14:36:59,397 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# 2024-02-23 14:36:59,405 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# 2024-02-23 14:36:59,540 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# 2024-02-23 14:36:59,564 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# 2024-02-23 14:36:59,578 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# 2024-02-23 14:36:59,581 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2024-02-23 14:36:59,582 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# 2024-02-23 14:36:59,602 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# 2024-02-23 14:36:59,636 - distributed.nanny - ERROR - Worker process died unexpectedly
# Traceback (most recent call last):
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/astro/users/fbcb/.conda/envs/lsdb_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/distributed/protocol/pickle.py:63, in dumps(x, buffer_callback, protocol)
#      62 try:
# ---> 63     result = pickle.dumps(x, **dump_kwargs)
#      64 except Exception:
#
# PicklingError: Can't pickle <function perform_join_on at 0x7fc944d57880>: it's not the same object as lsdb.dask.join_catalog_data.perform_join_on
#
# During handling of the above exception, another exception occurred:
#
# PicklingError                             Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/distributed/protocol/pickle.py:68, in dumps(x, buffer_callback, protocol)
#      67 buffers.clear()
# ---> 68 pickler.dump(x)
#      69 result = f.getvalue()
#
# PicklingError: Can't pickle <function perform_join_on at 0x7fc944d57880>: it's not the same object as lsdb.dask.join_catalog_data.perform_join_on
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 ens.source.persist().update_ensemble()
#
# File ~/.local/lib/python3.10/site-packages/tape/ensemble_frame.py:522, in _Frame.persist(self, **kwargs)
#     491 def persist(self, **kwargs):
#     492     """Persist this dask collection into memory
#     493
#     494     Doc string below derived from dask.base
#    (...)
#     520         The modifed frame backed by in-memory data
#     521     """
# --> 522     result = super().persist(**kwargs)
#     523     return self._propagate_metadata(result)
#
# File ~/.local/lib/python3.10/site-packages/dask/base.py:315, in DaskMethodsMixin.persist(self, **kwargs)
#     276 def persist(self, **kwargs):
#     277     """Persist this dask collection into memory
#     278
#     279     This turns a lazy Dask collection into a Dask collection with the same
#    (...)
#     313     dask.persist
#     314     """
# --> 315     (result,) = persist(self, traverse=False, **kwargs)
#     316     return result
#
# File ~/.local/lib/python3.10/site-packages/dask/base.py:951, in persist(traverse, optimize_graph, scheduler, *args, **kwargs)
#     949         else:
#     950             if client.get == schedule:
# --> 951                 results = client.persist(
#     952                     collections, optimize_graph=optimize_graph, **kwargs
#     953                 )
#     954                 return repack(results)
#     956 dsk = collections_to_dsk(collections, optimize_graph, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/distributed/client.py:3579, in Client.persist(self, collections, optimize_graph, workers, allow_other_workers, resources, retries, priority, fifo_timeout, actors, **kwargs)
#    3575 dsk = self.collections_to_dsk(collections, optimize_graph, **kwargs)
#    3577 names = {k for c in collections for k in flatten(c.__dask_keys__())}
# -> 3579 futures = self._graph_to_futures(
#    3580     dsk,
#    3581     names,
#    3582     workers=workers,
#    3583     allow_other_workers=allow_other_workers,
#    3584     resources=resources,
#    3585     retries=retries,
#    3586     user_priority=priority,
#    3587     fifo_timeout=fifo_timeout,
#    3588     actors=actors,
#    3589 )
#    3591 postpersists = [c.__dask_postpersist__() for c in collections]
#    3592 result = [
#    3593     func({k: futures[k] for k in flatten(c.__dask_keys__())}, *args)
#    3594     for (func, args), c in zip(postpersists, collections)
#    3595 ]
#
# File ~/.local/lib/python3.10/site-packages/distributed/client.py:3158, in Client._graph_to_futures(self, dsk, keys, workers, allow_other_workers, internal_priority, user_priority, resources, retries, fifo_timeout, actors)
#    3155 from distributed.protocol import serialize
#    3156 from distributed.protocol.serialize import ToPickle
# -> 3158 header, frames = serialize(ToPickle(dsk), on_error="raise")
#    3160 pickled_size = sum(map(nbytes, [header] + frames))
#    3161 if pickled_size > 10_000_000:
#
# File ~/.local/lib/python3.10/site-packages/distributed/protocol/serialize.py:353, in serialize(x, serializers, on_error, context, iterate_collection)
#     351 dumps, _, wants_context = families[name]
#     352 try:
# --> 353     header, frames = dumps(x, context=context) if wants_context else dumps(x)
#     354     header["serializer"] = name
#     355     return header, frames
#
# File ~/.local/lib/python3.10/site-packages/distributed/protocol/serialize.py:76, in pickle_dumps(x, context)
#      73     frames.append(f)
#      74     writeable.append(not f.readonly)
# ---> 76 frames[0] = pickle.dumps(
#      77     x,
#      78     buffer_callback=buffer_callback,
#      79     protocol=context.get("pickle-protocol", None) if context else None,
#      80 )
#      81 header = {
#      82     "serializer": "pickle",
#      83     "writeable": tuple(writeable),
#      84 }
#      86 return header, frames
#
# File ~/.local/lib/python3.10/site-packages/distributed/protocol/pickle.py:81, in dumps(x, buffer_callback, protocol)
#      79 try:
#      80     buffers.clear()
# ---> 81     result = cloudpickle.dumps(x, **dump_kwargs)
#      82 except Exception:
#      83     logger.exception("Failed to serialize %s.", x)
#
# File ~/.local/lib/python3.10/site-packages/cloudpickle/cloudpickle.py:1479, in dumps(obj, protocol, buffer_callback)
#    1477 with io.BytesIO() as file:
#    1478     cp = Pickler(file, protocol=protocol, buffer_callback=buffer_callback)
# -> 1479     cp.dump(obj)
#    1480     return file.getvalue()
#
# File ~/.local/lib/python3.10/site-packages/cloudpickle/cloudpickle.py:1245, in Pickler.dump(self, obj)
#    1243 def dump(self, obj):
#    1244     try:
# -> 1245         return super().dump(obj)
#    1246     except RuntimeError as e:
#    1247         if len(e.args) > 0 and "recursion" in e.args[0]:
#
# File ~/.local/lib/python3.10/site-packages/cloudpickle/cloudpickle.py:1290, in Pickler.reducer_override(self, obj)
#    1279 dispatch = dispatch_table
#    1281 # Implementation of the reducer_override callback, in order to
#    1282 # efficiently serialize dynamic functions and classes by subclassing
#    1283 # the C-implemented `pickle.Pickler`.
#    (...)
#    1287 # availability of both notions coincide on CPython's pickle, but it may
#    1288 # not be the case anymore when pypy implements protocol 5.
# -> 1290 def reducer_override(self, obj):
#    1291     """Type-agnostic reducing callback for function and classes.
#    1292
#    1293     For performance reasons, subclasses of the C `pickle.Pickler` class
#    (...)
#    1319       https://github.com/cloudpipe/cloudpickle/issues/248
#    1320     """
#    1321     t = type(obj)
#
# KeyboardInterrupt:

# %%
ens.object.persist().update_ensemble()

# %%
len(ens.object)
# Out:
# 714237

# %%
len(ens.source)
# Out:
# /astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 60.74 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# 2107462

# %%
#ens.source.query('~band_ztf_source.isnull()').update_ensemble()

# %%
len(ens.object)
# Out:
# /astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 30.43 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# 9033819

# %%
ens_ = ens.sample(frac=0.00001)

# %%
len(ens_.object)
# Out:
# /astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 0.96 GiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
ens_.dropna(table="source", subset="band_ztf_source")

# %%
calc_ = ens_.batch(
    determine_hc,
    'mjd_ztf_source', 'band_ztf_source', 
    'catflags_ztf_source', 
    'mag_ztf_source', 'magerr_ztf_source', 
    meta=my_meta,
    use_map=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 calc_ = ens.batch(
#       2     determine_hc,
#       3     'mjd_ztf_source', 'band_ztf_source',
#       4     'catflags_ztf_source',
#       5     'mag_ztf_source', 'magerr_ztf_source',
#       6     meta=my_meta,
#       7     use_map=True)
#
# File ~/.local/lib/python3.10/site-packages/tape/ensemble.py:1124, in Ensemble.batch(self, func, meta, by_band, use_map, on, label, *args, **kwargs)
#    1122 source_cols = list(self.source.columns)
#    1123 object_cols = list(self.object.columns)
# -> 1124 object_group_cols = [col for col in on if (col in object_cols) and (col not in source_cols)]
#    1126 if len(object_group_cols) > 0:
#    1127     object_col_dd = self.object[object_group_cols]
#
# TypeError: 'NoneType' object is not iterable

# %%
ens_.object.join(calc_).update_ensemble()

# %%
ens_.object.compute()
# Out:
# /astro/users/fbcb/.local/lib/python3.10/site-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 44.09 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
ens_.save_ensemble(
    ".",
    "ensemble_test",
    additional_frames=["result_1"],
)
